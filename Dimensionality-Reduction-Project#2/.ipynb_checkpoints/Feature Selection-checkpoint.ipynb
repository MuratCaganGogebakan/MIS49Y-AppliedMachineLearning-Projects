# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
botnet_df = pd.read_csv("Botnet.csv")

# %%
botnet_df.head()
# Out:
#    MI_dir_L0.1_weight  MI_dir_L0.1_mean  MI_dir_L0.1_variance  H_L0.1_weight  \
# 0            1.000000         98.000000          0.000000e+00       1.000000
# 1            1.931640         98.000000          1.818989e-12       1.931640
# 2            2.904273         86.981750          2.311822e+02       2.904273
# 3            3.902546         83.655268          2.040614e+02       3.902546
# 4            4.902545         81.685828          1.775746e+02       4.902545
#
#    H_L0.1_mean  H_L0.1_variance  HH_L0.1_weight  HH_L0.1_mean   HH_L0.1_std  \
# 0    98.000000     0.000000e+00         1.00000          98.0  0.000000e+00
# 1    98.000000     1.818989e-12         1.93164          98.0  1.348699e-06
# 2    86.981750     2.311822e+02         1.00000          66.0  0.000000e+00
# 3    83.655268     2.040614e+02         1.00000          74.0  0.000000e+00
# 4    81.685828     1.775746e+02         2.00000          74.0  9.536743e-07
#
#    HH_L0.1_magnitude  ...  HpHp_L0.1_mean  HpHp_L0.1_std  HpHp_L0.1_magnitude  \
# 0          98.000000  ...            98.0       0.000000            98.000000
# 1         138.592929  ...            98.0       0.000001           138.592929
# 2         114.856432  ...            66.0       0.000000           114.856432
# 3          74.000000  ...            74.0       0.000000            74.000000
# 4          74.000000  ...            74.0       0.000000            74.000000
#
#    HpHp_L0.1_radius  HpHp_L0.1_covariance  HpHp_L0.1_pcc       Device_Name  \
# 0      0.000000e+00                   0.0            0.0  Danmini_Doorbell
# 1      1.818989e-12                   0.0            0.0  Danmini_Doorbell
# 2      0.000000e+00                   0.0            0.0  Danmini_Doorbell
# 3      0.000000e+00                   0.0            0.0  Danmini_Doorbell
# 4      0.000000e+00                   0.0            0.0  Danmini_Doorbell
#
#    Attack  Attack_subType  label
# 0  gafgyt           combo      0
# 1  gafgyt           combo      0
# 2  gafgyt           combo      0
# 3  gafgyt           combo      0
# 4  gafgyt           combo      0
#
# [5 rows x 27 columns]

# %%
print(botnet_df.shape)
# Out:
# (7062606, 27)

# %%
del botnet_df["Device_Name"]
del botnet_df["Attack_subType"]
del botnet_df["label"]

# %%
# We deleted other botnets beacuse they were too infrequent compared to two major ones.
botnet_df = botnet_df.loc[botnet_df['Attack'].isin(["gafgyt", "mirai"])]

# %%
# Changed categorical data to numeric type so we can calculate correlations.
botnet_df['Attack'].replace(['gafgyt', 'mirai'],
                        [0, 1], inplace=True)

# %%
scaler = preprocessing.MinMaxScaler()
d = scaler.fit_transform(botnet_df)
botnet_df = pd.DataFrame(d, columns = botnet_df.columns)

# %%
array = botnet_df.values
Y = array[:,23]
X = array[:,0:23]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# Feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)

# Summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)

features = fit.transform(X)
# Summarize selected features
print(features[0:5,:])
# Out:
# [4.940e+05 1.125e+06 7.141e+05 4.940e+05 1.125e+06 7.141e+05 2.083e+04
#  6.703e+05 1.648e+04 3.955e+05 6.180e+02 6.598e-03 4.451e+00 2.083e+04
#  1.970e+05 1.719e+05 1.612e+05 6.703e+05 1.238e+03 4.149e+05 6.227e+02
#  5.582e-01 7.961e-02]
# [[7.510e-02 0.000e+00 7.510e-02 0.000e+00]
#  [7.510e-02 1.321e-17 7.510e-02 1.321e-17]
#  [5.332e-02 1.680e-03 5.332e-02 1.680e-03]
#  [4.675e-02 1.482e-03 4.675e-02 1.482e-03]
#  [4.286e-02 1.290e-03 4.286e-02 1.290e-03]]

# %%
botnet_df.head()
# Out:
#    MI_dir_L0.1_weight  MI_dir_L0.1_mean  MI_dir_L0.1_variance  H_L0.1_weight  \
# 0        8.423018e-08          0.000159          0.000000e+00   8.423018e-08
# 1        1.627024e-07          0.000159          2.158881e-20   1.627024e-07
# 2        2.446274e-07          0.000141          2.743802e-06   2.446274e-07
# 3        3.287122e-07          0.000136          2.421918e-06   3.287122e-07
# 4        4.129422e-07          0.000132          2.107558e-06   4.129422e-07
#
#    H_L0.1_mean  H_L0.1_variance  HH_L0.1_weight  HH_L0.1_mean   HH_L0.1_std  \
# 0     0.000159     0.000000e+00    1.193092e-07      0.000137  0.000000e+00
# 1     0.000159     2.158881e-20    2.304624e-07      0.000137  1.012273e-10
# 2     0.000141     2.743802e-06    1.193092e-07      0.000092  0.000000e+00
# 3     0.000136     2.421918e-06    1.193092e-07      0.000104  0.000000e+00
# 4     0.000132     2.107558e-06    2.386184e-07      0.000104  7.157849e-11
#
#    HH_L0.1_magnitude  ...  HH_jit_L0.1_mean  HH_jit_L0.1_variance  \
# 0           0.000136  ...          0.000536              0.000000
# 1           0.000193  ...          0.000258              0.002906
# 2           0.000160  ...          0.000536              0.000000
# 3           0.000103  ...          0.000536              0.000000
# 4           0.000103  ...          0.000268              0.002910
#
#    HpHp_L0.1_weight  HpHp_L0.1_mean  HpHp_L0.1_std  HpHp_L0.1_magnitude  \
# 0      5.656249e-07        0.000137   0.000000e+00             0.000137
# 1      1.092583e-06        0.000137   2.476693e-10             0.000193
# 2      5.656249e-07        0.000092   0.000000e+00             0.000160
# 3      5.656249e-07        0.000104   0.000000e+00             0.000103
# 4      5.656249e-07        0.000104   0.000000e+00             0.000103
#
#    HpHp_L0.1_radius  HpHp_L0.1_covariance  HpHp_L0.1_pcc  Attack
# 0      0.000000e+00                   0.0            0.0     0.0
# 1      2.904020e-19                   0.0            0.0     0.0
# 2      0.000000e+00                   0.0            0.0     0.0
# 3      0.000000e+00                   0.0            0.0     0.0
# 4      0.000000e+00                   0.0            0.0     0.0
#
# [5 rows x 24 columns]
